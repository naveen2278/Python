# %%
# list
n=int(input())
l=[]
for i in range(n):
    l.append(int(input()))
print(l)
# Out:
# [45, 56, 5, 5, 5]

# %%
l = [10, 20, 30, 40, 50]
print(l.count(10))  # 1
# Out:
# 1

# %%
l = [10, 20, 30, 40, 50]
print(l.index(10))

# %%
l = [10, 20, 30, 40, 50]
print(l.append(10))

# %%
l = [10, 20, 30, 40, 50]
print(l.insert(1, 10))

# %%
l = [10, 20, 30, 40, 50]
l1 = [100, 200, 300]
print(l.extend(l1))
print(l)
# Out:
# None
# [10, 20, 30, 40, 50, 100, 200, 300]

# %%
l= [10, 20, 30, 40, 50]
print(l.pop())
print(l)

# %%
l = [10, 20, 30, 40, 50]
l.remove(10)
print(l)

# %%
l= [10, 20, 30, 40, 50]
l.sort()
print(l)
l.sort(reverse=True)
print(l)

# %%
print(min(l))
print(sum(l))
print(max(l))
# Out:
# 10
# 750
# 300

# %%
n=int(input())
lst = []
for i in range(n):
    lst.append(int(input()))
sum = 0
for i in lst:
    sum+=i
print(lst)
# Out:
# [45, 54, 58, 854, 8543]

# %%
n = int(input())
lst = list(map(int, input().split()))[:n]
max =  lst[0]
for i in range(1, n):
    if lst[i] > max:
        max = lst[i]
print(max)
# Out:
# 22

# %%
n = int(input())
lst = list(map(int, input().split()))[:n]
max_val = lst[0]
for i in range(1, n):
    if lst[i] > max_val:
        max_val = lst[i]
print(max_val)
