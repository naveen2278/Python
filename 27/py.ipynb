# %%
n = int(input())
for i in range(1, n + 1):
    print(i, end=" ")

# %%
n= int(input())
for i in range(1, 10):
    print(f"{n} x {i} = {n * i}")
# Out:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90

# %%
n = int(input())
fact = 1
for i in range(1, n + 1):
    fact *= i
print(fact)

# %%
n = int(input())
v=iv=amt=0
for i in range(n):
    i = int(input())
    if i% 100 == 0 and i>0:
        v += i
        amt += 1
    else:
        iv += i
print(v)
print(iv)

# %%
n = int(input())

rev = 0
while n > 0:
    digit = n % 10
    rev = rev * 10 + digit
    n //= 10

print(rev)

# %%
n = int(input())
total = 0
while n > 0:
    total += n % 10
    n //= 10
print(total)
